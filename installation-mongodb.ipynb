# %% [markdown]
# ## Installation MongoDB

# %%
from IPython.display import Image
Image('C:/Users/levog/OneDrive/Images/Camera Roll/install.png')

# %% [markdown]
# Nous commençons par installer le logiciel MondoDB. La version 4.4.2 est choisie, en version complète et en tant que "network service".
#
# Nous ajoutons également la variable d'environnement Mango, dont le chemin est situé dans le dossier C:\Program Files\MongoDB\Server\4.4\bin, cela permettra de lancer une commande Mango dans un terminal sans avoir besoin de spécifier dans quel dossier se trouve le programme.
#
# Dans ce dossier en particulier, nous trouvons mongo.exe, mongod.exe ainsi que mongos.exe.

# %%
from IPython.display import Image
Image('C:/Users/levog/OneDrive/Images/Camera Roll/env.png')

# %% [markdown]
# Nous pouvons observer qu'en lançant mongo sur un terminal de commandes, la connexion à un serveur local et un id de session se fait effectivement. La version est 4.4.2.

# %%
from IPython.display import Image
Image('C:/Users/levog/OneDrive/Images/Camera Roll/shell.png')

# %% [markdown]
# Nous créons maintenant un répertoire à la racine de l'ordinateur où seront stockées les bases des données grâce aux commandes :
#
# - cd C:\
#
# - md "\data\db"
#
# Nous créons ensuite le chemin d'enregistrement des BDD avec la commande :
#
# - C:\Users\utilisateur>"C:\Program Files\MongoDB\Server\4.4\bin\mongod.exe" --dbpath="C:\data\db"

# %% [markdown]
# Nous pouvons maintenant commencer à travailler sur les bases de données, la connexion et la visualisation se feront dans le notebook movies-spinoff-mondb.ipynb
